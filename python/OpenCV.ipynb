# %%
from pycoreimage.pyci import show
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
from IPython.core.display import display, HTML
display(HTML("<style>.contatiner {width: 90 % !important; }</style>"))
# Out:
# <style>.contatiner {width: 90 % !important; }</style>

# %%
cv.__version__
# Out:
# '4.5.2'

# %%
np.__version__
# Out:
# '1.20.3'

# %%
img = cv.imread('resources/SampleImage.jpg')
gray = cv.cvtColor(img, cv.COLOR_RGBA2BGR)

plt.imshow(gray)
plt.title('origin')
plt.show()

# %%
# http://www.lenna.org
lena = cv.imread('/Users/birney1/Documents/lena_full.jpg')
lenargb = cv.cvtColor(lena, cv.COLOR_RGBA2BGR)
plt.figure(figsize = (50,20))
plt.imshow(lenargb)
plt.title('lena')
plt.show()

# %%
plt.imshow?
